# %%
import geopandas as gpd
import pandas as pd
import transbigdata as tbd

# %% [markdown]
# ## Variable
# Socioeconomic Factors:
# - Population density
# - Gender, Income level, Education level, Age
# - Psychological attitudes
#
# Built Environment Factors:
# - (Got) Land use patterns
# - Public transport facilities distribution
# - Public fcility diversity
# - (Got) Proximity to highways
# - (Got) Road network density
# - Metro and bus accessibility
# - Power outages
#
# Charging Facility Attributes
# - (Got) Accessibility of charging facilities
# - (Got) Charging and parking price
# - Location convenience
# - Network topology
#
# Temporal Factors
# - (Got) Time of day
# - (Got) End of day charging
# - (Got) Charging duration
#
# Environmental Factors
# - (Got) Weather conditions
# - Extreme weather events
# - Flood inundation levels

# %%
buildings = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_buildings_a_free_1.shp')
print(buildings.columns)
print(buildings.shape)
buildings.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'type', 'geometry'], dtype='object')
# (371377, 6)
#      osm_id  code    fclass  \
# 0  23398992  1500  building
# 1  23399230  1500  building
# 2  25071244  1500  building
# 3  25589595  1500  building
# 4  25590249  1500  building
#
#                                                 name        type  \
# 0                             亞洲國際博覽館 AsiaWorld-Expo  commercial
# 1  機場管理局維修總部 Airport Authority Maintenance Headqu...      public
# 2                      飛行培訓中心 Flight Training Centre      office
# 3          國際金融中心二期 Two International Finance Centre        None
# 4               環球貿易廣場 International Commerce Centre       tower
#
#                                             geometry
# 0  POLYGON ((113.94083 22.32151, 113.94367 22.322...
# 1  POLYGON ((113.93362 22.31965, 113.93486 22.320...
# 2  POLYGON ((113.93322 22.29843, 113.93323 22.298...
# 3  POLYGON ((114.15895 22.28523, 114.15899 22.285...
# ...

# %%
buildings.plot()
# Out:
# <Axes: >

# %%
landuse = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_landuse_a_free_1.shp')
print(landuse.columns)
print(landuse.shape)
landuse.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# (121223, 5)
#     osm_id  code          fclass                               name  \
# 0  4182605  7202            park               維多利亞公園 Victoria Park
# 1  4977404  7202            park                  九龍公園 Kowloon Park
# 2  9561506  7210  nature_reserve  周公島具特殊科學價值地點 Sunshine Island SSSI
# 3  9561615  7210  nature_reserve                                细担岛
# 4  9762499  7210  nature_reserve                                野狸岛
#
#                                             geometry
# 0  POLYGON ((114.18594 22.28351, 114.18621 22.283...
# 1  POLYGON ((114.16828 22.30104, 114.16854 22.301...
# 2  POLYGON ((114.04672 22.25934, 114.04673 22.259...
# 3  POLYGON ((114.12232 21.96516, 114.12237 21.965...
# 4  POLYGON ((113.57981 22.27914, 113.57983 22.279...

# %%
landuse[['fclass']].drop_duplicates().shape
# Out:
# (20, 1)

# %%
landuse.plot()
# Out:
# <Axes: >

# %%
natural = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_natural_a_free_1.shp')
print(natural.columns)
print(natural.shape)
natural.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# (702, 5)
#      osm_id  code fclass                      name  \
# 0   6075911  4141  beach  大浪灣泳灘 Big Wave Bay Beach
# 1   9765202  4141  beach                      None
# 2   9770238  4141  beach                      None
# 3  26519927  4141  beach   盧鬚城泳灘 Lo So Shing Beach
# 4  35900298  4141  beach          貝澳泳灘 Pui O Beach
#
#                                             geometry
# 0  POLYGON ((114.24646 22.24649, 114.24771 22.247...
# 1  POLYGON ((111.22449 21.47391, 111.22511 21.473...
# 2  POLYGON ((111.41782 21.51985, 111.4215 21.5209...
# 3  POLYGON ((114.12216 22.20509, 114.1224 22.2050...
# 4  POLYGON ((113.9728 22.24043, 113.97297 22.2407...

# %%
natural.plot()
# Out:
# <Axes: >

# %%
places = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_places_a_free_1.shp')
print(places.columns)
print(places.shape)
places.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'population', 'name', 'geometry'], dtype='object')
# (741, 6)
#      osm_id  code  fclass  population                      name  \
# 0   9208147  1020  island           0                        官屿
# 1   9209165  1020  island           0                      None
# 2   9215006  1020  island           0                      None
# 3  15957610  1020  island           0  南果洲 South Ninepin Island
# 4  12927100  1020  island           0                 蒲台 Po Toi
#
#                                             geometry
# 0  POLYGON ((117.1045 23.38726, 117.10452 23.3873...
# 1  POLYGON ((117.01796 23.57883, 117.01802 23.578...
# 2  POLYGON ((117.06029 23.57152, 117.06031 23.571...
# 3  POLYGON ((114.34779 22.25668, 114.34781 22.256...
# 4  POLYGON ((114.24994 22.16611, 114.24995 22.166...

# %%
places.plot()
# Out:
# <Axes: >

# %%
pofw = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_pofw_a_free_1.shp')
print(pofw.columns)
print(pofw.shape)
pofw.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# (823, 5)
#       osm_id  code              fclass                         name  \
# 0   98478375  3100           christian  聖德肋撒堂 Saint Teresa's Church
# 1  100104498  3600              taoist           極樂洞善堂 Kik Lok Tung
# 2  100228388  3100           christian           基灣堂 Kei Wan Church
# 3  103291792  3600              taoist           天后廟 Tin Hau Temple
# 4  107497695  3101  christian_anglican   聖約翰座堂 St. John's Cathedral
#
#                                             geometry
# 0  POLYGON ((114.17785 22.32631, 114.17791 22.326...
# 1  POLYGON ((114.22381 22.27822, 114.22399 22.278...
# 2  POLYGON ((114.22246 22.28032, 114.22248 22.280...
# 3  POLYGON ((114.1597 22.3285, 114.15983 22.32865...
# 4  POLYGON ((114.15942 22.27892, 114.15946 22.278...

# %%
pofw.plot()
# Out:
# <Axes: >

# %%
pois = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_pois_a_free_1.shp')
print(pois.columns)
print(pois.shape)
pois.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# (52812, 5)
#     osm_id  code         fclass  \
# 0  4182605  2204           park
# 1  4977404  2204           park
# 2  5020555  2251  sports_centre
# 3  5108618  2252          pitch
# 4  6075662  2082         school
#
#                                                 name  \
# 0                               維多利亞公園 Victoria Park
# 1                                  九龍公園 Kowloon Park
# 2                          修頓遊樂場 Southorn Playground
# 3                  京士柏曲棍球場 King's Park Hockey Ground
# 4  崇真小學暨幼稚園 Tsung Tsin Primary School and Kinderg...
#
#                                             geometry
# 0  POLYGON ((114.18594 22.28351, 114.18621 22.283...
# 1  POLYGON ((114.16828 22.30104, 114.16854 22.301...
# 2  POLYGON ((114.17167 22.27658, 114.17173 22.276...
# 3  POLYGON ((114.17699 22.3074, 114.17751 22.3075...
# 4  POLYGON ((114.16724 22.32896, 114.16743 22.329...

# %%
pois.plot()
# Out:
# <Axes: >

# %%
railways = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_railways_free_1.shp')
print(railways.columns)
print(railways.shape)
railways.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'layer', 'bridge', 'tunnel',
#        'geometry'],
#       dtype='object')
# (22348, 8)
#     osm_id  code     fclass                                 name  layer  \
# 0  4181592  6103     subway           港鐵機場快綫 MTR Airport Express      1
# 1  4181898  6103     subway  大嶼山及機場鐵路 Lantau and Airport Railway     -2
# 2  4182662  6103     subway           港鐵機場快綫 MTR Airport Express      2
# 3  4338940  6108  funicular                       山頂纜車 Peak Tram      0
# 4  4959070  6103     subway           港鐵機場快綫 MTR Airport Express      0
#
#   bridge tunnel                                           geometry
# 0      T      F  LINESTRING (113.94339 22.32225, 113.94222 22.322)
# 1      F      T  LINESTRING (114.05075 22.34109, 114.05044 22.3...
# 2      T      F  LINESTRING (114.12591 22.34832, 114.12518 22.3...
# 3      F      F  LINESTRING (114.1503 22.27111, 114.15145 22.27...
# 4      F      F  LINESTRING (113.9622 22.29779, 113.96138 22.29...

# %%
railways.plot()
# Out:
# <Axes: >

# %%
roads = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_roads_free_1.shp')
print(roads.columns)
print(roads.shape)
roads.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'ref', 'oneway', 'maxspeed',
#        'layer', 'bridge', 'tunnel', 'geometry'],
#       dtype='object')
# (842879, 11)
#     osm_id  code        fclass                      name   ref oneway  \
# 0  4195000  5153       footway                      None  None      B
# 1  4338869  5112         trunk  黃竹坑道 Wong Chuk Hang Road     1      F
# 2  4338992  5121  unclassified             山頂道 Peak Road  None      B
# 3  4339014  5124    pedestrian          夏力道 Harlech Road  None      B
# 4  4793007  5113       primary           彌敦道 Nathan Road  None      F
#
#    maxspeed  layer bridge tunnel  \
# 0         0      0      F      F
# 1        50      0      F      F
# 2         0      0      F      F
# 3         0      0      F      F
# 4         0      0      F      F
#
#                                             geometry
# 0  LINESTRING (114.18562 22.28266, 114.1856 22.28...
# 1  LINESTRING (114.16215 22.24868, 114.16294 22.2...
# ...

# %%
roads.plot()
# Out:
# <Axes: >

# %%
traffic = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_traffic_a_free_1.shp')
print(traffic.columns)
print(traffic.shape)
traffic.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# (13785, 5)
#      osm_id  code fclass               name  \
# 0   4339096  5311    dam               None
# 1  23368178  5311    dam        主壩 Main Dam
# 2  23368179  5311    dam       草壩 Grass Dam
# 3  23368182  5311    dam  菠蘿壩 Pineapple Dam
# 4  23368200  5311    dam               None
#
#                                             geometry
# 0  POLYGON ((114.13635 22.26416, 114.13642 22.264...
# 1  POLYGON ((114.14754 22.37892, 114.14902 22.380...
# 2  POLYGON ((114.14338 22.38034, 114.14364 22.380...
# 3  POLYGON ((114.14381 22.3841, 114.14384 22.3843...
# 4  POLYGON ((114.02079 22.37407, 114.02079 22.374...

# %%
traffic.plot()
# Out:
# <Axes: >

# %%
transport = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_transport_a_free_1.shp')
print(transport.columns)
print(transport.shape)
transport.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# (1592, 5)
#      osm_id  code           fclass  \
# 0  26305418  5622      bus_station
# 1  28069671  5601  railway_station
# 2  28104047  5622      bus_station
# 3  28119003  5622      bus_station
# 4  28808692  5622      bus_station
#
#                                                 name  \
# 0                    中環 (港澳碼頭) Central (Macau Ferry)
# 1                                         機場 Airport
# 2  將軍澳公共運輸交匯處 Tseung Kwan O Public Transport Inte...
# 3             康盛花園巴士總站 Hong Sing Garden Bus Terminus
# 4           小西灣邨巴士總站 Siu Sai Wan Estate Bus Terminus
#
#                                             geometry
# 0  POLYGON ((114.14956 22.28835, 114.1497 22.2887...
# 1  POLYGON ((113.93586 22.31732, 113.93596 22.317...
# 2  POLYGON ((114.25999 22.30875, 114.26056 22.308...
# 3  POLYGON ((114.25388 22.3185, 114.2539 22.31876...
# 4  POLYGON ((114.24882 22.26307, 114.24897 22.263...

# %%
transport.plot()
# Out:
# <Axes: >

# %%
water = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_water_a_free_1.shp')
print(water.columns)
print(water.shape)
water.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# (57862, 5)
#     osm_id  code     fclass                        name  \
# 0  4339370  8201  reservoir  薄扶林水塘 Pok Fu Lam Reservoir
# 1  9559503  8200      water                        None
# 2  9559699  8200      water                        None
# 3  9559798  8200      water                        None
# 4  9559953  8202  riverbank                        None
#
#                                             geometry
# 0  POLYGON ((114.13644 22.2649, 114.13645 22.2649...
# 1  POLYGON ((116.23445 22.96959, 116.2349 22.9698...
# 2  POLYGON ((115.79001 22.82382, 115.79026 22.824...
# 3  POLYGON ((115.61096 22.91185, 115.61109 22.912...
# 4  POLYGON ((114.0941 22.99213, 114.10438 23.0032...

# %%
water.plot()
# Out:
# <Axes: >

# %%
waterways = gpd.read_file('guangdong_latest_shapefile/guangdong_latest_shapefile/gis_osm_waterways_free_1.shp')
print(waterways.columns)
print(waterways.shape)
waterways.head(5)
# Out:
# Index(['osm_id', 'code', 'fclass', 'width', 'name', 'geometry'], dtype='object')
# (28185, 6)
#      osm_id  code  fclass  width        name  \
# 0  23212250  8102  stream      0        None
# 1  23633090  8102  stream      0  西高山北坑 (W4)
# 2  23638666  8102  stream      0        None
# 3  23638683  8102  stream      0        龍虎東坑
# 4  23638866  8102  stream      0        None
#
#                                             geometry
# 0  LINESTRING (114.13712 22.27744, 114.13795 22.2...
# 1  LINESTRING (114.13654 22.275, 114.13591 22.275...
# 2  LINESTRING (114.13044 22.27579, 114.13051 22.2...
# 3  LINESTRING (114.13637 22.27973, 114.13647 22.2...
# 4  LINESTRING (114.14915 22.25499, 114.14915 22.2...

# %%
waterways.plot()
# Out:
# <Axes: >

# %%
districts = gpd.read_file('UrbanEVSupplemental\shenzhen_districts\Shenzhen.shp')
print(districts.columns)
print(districts.shape)
districts.head(5)
# Out:
# Index(['OBJECTID', 'TAZID', 'AREA', 'X', 'Y', 'ZONE', 'LENG_ROAD',
#        'SHAPE_Leng', 'SHAPE_Area', 'geometry'],
#       dtype='object')
# (491, 10)
#    OBJECTID   TAZID   AREA           X          Y   ZONE  LENG_ROAD  \
# 0         1  1054.0  11.49  114.333530  22.783052  781.0     10.135
# 1         2  1052.0  17.07  114.282465  22.789111  775.0      6.368
# 2         3   850.0   2.85  114.322722  22.791482  780.0      4.822
# 3         4  1066.0   1.57  113.910301  22.521287  307.0      7.130
# 4         5  1068.0   1.41  113.918680  22.517837  306.0      7.084
#
#      SHAPE_Leng  SHAPE_Area                                           geometry
# 0  25856.846986  13581804.0  POLYGON ((12727715 2609219, 12727838 2609098, ...
# 1  30117.841314  20191527.5  POLYGON ((12721609 2609078, 12721630 2608932, ...
# 2  10307.116136   3375499.0  POLYGON ((12726477 2609132, 12726623 2609056, ...
# 3   5552.707185   1857995.0  POLYGON ((12680558 2573496, 12680096 2573463, ...
# ...

# %%
zone = pd.read_csv('zone-information.csv')
print(zone.columns)
print(zone.shape)
zone.head(5)
# Out:
# Index(['TAZID', 'longitude', 'latitude', 'charge_count', 'area', 'perimeter'], dtype='object')
# (275, 6)
#    TAZID   longitude   latitude  charge_count          area  perimeter
# 0   1066  113.910301  22.521287            40  1.577893e+06  5119.3013
# 1   1068  113.918680  22.517837           271  1.405269e+06  5460.2638
# 2   1096  113.919902  22.531428            70  1.074909e+06  4437.0676
# 3    326  113.931887  22.535775           106  1.963022e+06  6447.5728
# 4   1085  113.925789  22.521524            59  3.878395e+05  2688.3240

# %%
districts[districts['X']==113.]
